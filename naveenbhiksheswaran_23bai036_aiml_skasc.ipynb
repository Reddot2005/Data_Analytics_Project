# %%
#importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
titanic=pd.read_csv('train.csv',index_col="PassengerId")

# %%
#view
titanic
titanic.shape
titanic.apply(pd.isnull).sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#coverting categorical to numerical using mapp function
titanic['Sex']=titanic['Sex'].map({'male':0,'female':1})

# %%
#view number of columns
titanic.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#checking the datatype of sex
titanic["Sex"].dtypes
# Out:
# dtype('int64')

# %%
#view number of rows and columns
titanic.shape
# Out:
# (891, 11)

# %%
titanic["Age"]>35
# Out:
# PassengerId
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
#droping cabin column
titanic=titanic.drop("Cabin",axis=1)
titanic.shape
# Out:
# (891, 10)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
# ...                                                        ...  ...   ...
# ...

# %%
#cheching the number of null values in each column
titanic.apply(pd.isnull).sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
#filling missing age values with the median
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)
# Out:
# <ipython-input-108-d4dc62d1860c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Age'].fillna(titanic['Age'].median(), inplace=True)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
# ...                                                        ...  ...   ...
# ...

# %%
titanic.apply(pd.isnull).sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)
# Out:
# <ipython-input-111-2f95f2f56f79>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# %%
titanic.apply(pd.isnull).sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# Grouping data to calculate survival counts based on gender
survived_by_gender = titanic[titanic['Survived'] == 1]['Sex'].value_counts()

# Pie chart visualization
plt.figure(figsize=(8, 8))
colors = ['skyblue', 'lightcoral']
plt.pie(survived_by_gender, labels=survived_by_gender.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.1, 0], textprops={'fontsize': 12})
plt.title('Pie Chart of Survival by Gender', fontsize=14)
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle.

# Display the plot
plt.show()

# %%
# Create scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(titanic['Sex'], titanic['Survived'], c='r', cmap='viridis', edgecolors='black')
plt.title('Sex vs Survived')
plt.xlabel('Sex (0 = Male, 1 = Female)')
plt.ylabel('Survived (0 = Dead, 1 = Survived)')
plt.yticks([0, 1], ['Dead', 'Survived'])
plt.xticks([0, 1], ['Male', 'Female'])
plt.grid(True)
plt.show()
# Out:
# <ipython-input-15-0fbf47b6c531>:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(titanic['Sex'], titanic['Survived'], c='r', cmap='viridis', edgecolors='black')

# %%
# Create cross-tabulation of Sex and Survival
cross_tab = pd.crosstab(titanic['Sex'], titanic['Survived'])

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab, annot=True, fmt='d')

plt.show()

# %%
# Survival by gender
plt.subplot(2, 2, 1)
sns.countplot(x='Sex', hue='Survived', data=titanic)
plt.title('Survival by Gender')
# Out:
# Text(0.5, 1.0, 'Survival by Gender')

# %%
# Age distribution and survival
plt.subplot(2, 2, 3)
sns.histplot(titanic, x='Age', hue='Survived', kde=True, bins=30)
plt.title('Age Distribution and Survival')
# Out:
# Text(0.5, 1.0, 'Age Distribution and Survival')

# %%
# Survival by class
plt.subplot(2, 2, 2)
sns.countplot(x='Pclass', hue='Survived', data=titanic)
plt.title('Survival by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Survival by Passenger Class')

# %%
# Fare distribution and survival
plt.subplot(2, 2, 4)
sns.histplot(titanic, x='Fare', hue='Survived', kde=True, bins=30)
plt.title('Fare Distribution and Survival')

plt.tight_layout()
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 6))
correlation = titanic[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.rugplot(data=titanic, x='Survived')
plt.show()

# More customized rugplot
plt.figure(figsize=(10, 4))
sns.rugplot(data=titanic, x='Survived',
            height=0.5,          # Height of the lines
            color='red',         # Color of the lines
            alpha=0.5)           # Transparency of the lines
plt.title('Distribution of Values')
plt.xlabel('Values')
plt.show()

# %%
# Summary statistics
summary_stats = titanic.describe(include='all')
print(summary_stats)
# Out:
#           Survived      Pclass                     Name         Sex  \
# count   891.000000  891.000000                      891  891.000000
# unique         NaN         NaN                      891         NaN
# top            NaN         NaN  Braund, Mr. Owen Harris         NaN
# freq           NaN         NaN                        1         NaN
# mean      0.383838    2.308642                      NaN    0.352413
# std       0.486592    0.836071                      NaN    0.477990
# min       0.000000    1.000000                      NaN    0.000000
# 25%       0.000000    2.000000                      NaN    0.000000
# 50%       0.000000    3.000000                      NaN    0.000000
# 75%       1.000000    3.000000                      NaN    1.000000
# max       1.000000    3.000000                      NaN    1.000000
#
#                Age       SibSp       Parch  Ticket        Fare Embarked
# count   891.000000  891.000000  891.000000     891  891.000000      891
# ...

# %%
# Visualizing survival rates by different features
plt.figure(figsize=(15, 8))

# %%
plt.figure(figsize=(8, 4))
sns.rugplot(x='Age', hue='Survived', data=titanic, height=0.3)
plt.title("Rugplot of Age with Survival")
plt.show()

# %%
# ECDF Plot
plt.figure(figsize=(8, 4))
sns.ecdfplot(x='Age', hue='Survived', data=titanic)
plt.title("ECDF Plot of Age with Survival")
plt.show()

# %%
# Lineplot
plt.figure(figsize=(8, 4))
sns.lineplot(x='Age', y='Survived', data=titanic)
plt.title("Lineplot of Age with Survival Rate")
plt.show()

# %%
# Pairplot (Focus on 'survived', 'age', and 'sex')
sns.pairplot(titanic, hue='Survived', vars=['Age'], corner=True)
plt.suptitle("Pairplot of Age with Survival", y=1.02)
plt.show()

# %%
# Stripplot
plt.figure(figsize=(8, 4))
sns.stripplot(x='Survived', y='Age', hue='Sex', data=titanic, jitter=True, dodge=True)
plt.title("Stripplot of Age by Survival and Gender")
plt.show()

# %%
# FacetGrid (FacetGrid allows flexible multi-plot grids)
g = sns.FacetGrid(titanic, col="Survived", row="Sex", margin_titles=True)
g.map(sns.histplot, "Age", kde=True, bins=20)
g.fig.suptitle("FacetGrid: Age Distribution by Survival and Gender", y=1.02)
plt.show()

# %%
# Jointplot
sns.jointplot(x='Age', y='Survived', data=titanic, kind='scatter', hue='Sex')
plt.suptitle("Jointplot: Age vs Survival", y=1.02)
plt.show()

# %%
# Create the box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Survived', y='Age', data=titanic)

# Add labels and title
plt.title('Box Plot of Age by Survival Status', fontsize=14)
plt.xlabel('Survived (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Age', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Example: Count plot for Survived vs Gender
plt.figure(figsize=(8, 6))
sns.countplot(data=titanic, x='Survived', hue='Sex', palette='Set2')

# Adding labels and title
plt.title('Countplot of Survival by Gender', fontsize=14)
plt.xlabel('Survived', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Gender')

# Display the plot
plt.show()

# %%
# Plotting the histogram with a polygon
plt.figure(figsize=(8, 6))
sns.histplot(data=titanic, x='Age', hue='Survived', kde=True, element='step', stat='density', common_norm=False)

# Adding labels and title
plt.title('Histogram Polygon of Age by Survival', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(title='Survived', labels=['Did Not Survive (0)', 'Survived (1)'])

# Display the plot
plt.show()

# %% [markdown]
# #conclusions and insights
#
# Key Findings:
#
# Gender (Sex) as Primary Survival Predictor:
#
#
# Being female was the strongest predictor of survival on the Titanic
# Women had significantly higher survival rates compared to men
# This aligns with the historical "women and children first" protocol followed during the disaster
#
#
# Age as Secondary Factor:
#
#
# Age played a notable but lesser role in survival outcomes
# Young children showed better survival rates
# Middle-aged men had the lowest survival probability
# The age distribution of survivors skewed younger than that of non-survivors
#
#
# Limited Impact of Other Variables:
#
#
# Other parameters like passenger class, cabin location, and other demographic factors showed less significant correlations with survival
# While these variables might have had some influence, their predictive power was substantially lower than sex and age
